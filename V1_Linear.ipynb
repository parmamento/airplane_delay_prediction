# %% [markdown]
# <h2 style='text-align: center;'> Data Science Technology and Systems </h2>
# <h3 style='text-align: center;'> Final Assignment: Predicting Airplane Delays </h3>
# <h3 style='text-align: center;'> Part B – On Cloud </h3>
# <h3 style='text-align: center;'> V1 - Linear Estimator </h3>
# <h4 style='text-align: center;'> Pauline Armamento - u3246782 </h4>

# %%
import time
start = time.time()
import warnings, requests, zipfile, io
warnings.simplefilter('ignore')
import pandas as pd
import numpy as np
from scipy.io import arff


import os
import boto3
import sagemaker
import subprocess
from sagemaker import image_uris
from sagemaker.image_uris import retrieve
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, roc_curve, auc, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# Matplotlib is building the font cache; this may take a moment.

# %%
# Load CSV files into dataframes
df1 = pd.read_csv('combined_csv_v1.csv')
df2 = pd.read_csv('combined_csv_v2.csv')

# %%
# Check for missing values in df1
print(df1.isnull().sum())
# Out:
# target             0
# Distance           0
# Quarter_2          0
# Quarter_3          0
# Quarter_4          0
#                   ..
# DepHourofDay_19    0
# DepHourofDay_20    0
# DepHourofDay_21    0
# DepHourofDay_22    0
# DepHourofDay_23    0
# Length: 94, dtype: int64

# %%
# Remove rows with missing values
df1.dropna(inplace=True)

# %%
df1.shape
# Out:
# (1635590, 94)

# %%
# Split the data into train (70%), and then split the remaining 30% into validation (15%) and test (15%)
class_column = 'target'  # Target variable for stratified splitting

# Split the data into training (70%) and temp (30%)
train_data, temp_data = train_test_split(df1, test_size=0.3, random_state=0, stratify=df1[class_column])

# Split the temp data into validation (15%) and testing (15%)
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=0, stratify=temp_data[class_column])

# Print the shapes of the datasets
print("Training set shape:", train_data.shape)
print("Validation set shape:", val_data.shape)
print("Testing set shape:", test_data.shape)

# Save these splits to CSV files for uploading to S3
train_file = 'train.csv'
val_file = 'validation.csv'
test_file = 'test.csv'

train_data.to_csv(train_file, index=False, header=False)
val_data.to_csv(val_file, index=False, header=False)
test_data.to_csv(test_file, index=False, header=False)
# Out:
# Training set shape: (1144913, 94)
# Validation set shape: (245338, 94)
# Testing set shape: (245339, 94)

# %%
import boto3

s3_client = boto3.client('s3')
response = s3_client.list_buckets()

print("Existing buckets:")
for bucket in response['Buckets']:
    print(f'  {bucket["Name"]}')
# Out:
# Existing buckets:
#   c135321a3429026l8211909t1w07796198217-flightbucket-wiycexlqxuki

# %%
# Function to upload CSV files to S3
s3_resource = boto3.Session().resource('s3')

def upload_s3_csv(filename, folder, dataframe):
    csv_buffer = io.StringIO()
    dataframe.to_csv(csv_buffer, header=False, index=False)
    s3_resource.Bucket(bucket).Object(os.path.join(prefix, folder, filename)).put(Body=csv_buffer.getvalue())

# Define the S3 bucket and prefix
bucket='c135321a3429026l8211909t1w07796198217-flightbucket-wiycexlqxuki' #change accordingly
prefix = 'flight-delay-project'

# Upload data to S3
upload_s3_csv('train.csv', 'train', train_data)
upload_s3_csv('validation.csv', 'validate', val_data)
upload_s3_csv('test.csv', 'test', test_data)

# %%
import sagemaker
from sagemaker.serializers import CSVSerializer
from sagemaker.amazon.amazon_estimator import RecordSet
import boto3

# Instantiate the LinearLearner estimator object with 1 ml.m4.xlarge
num_classes = len(pd.unique(train_data[class_column]))
classifier_estimator = sagemaker.LinearLearner(role=sagemaker.get_execution_role(),
                                              instance_count=1,
                                              instance_type='ml.m4.xlarge',
                                              predictor_type='binary_classifier',
                                              binary_classifier_model_selection_criteria = 'cross_entropy_loss')

# %%
# Create train, validate, and test records
train_records = classifier_estimator.record_set(train_data.values[:, 1:].astype(np.float32), train_data.values[:, 0].astype(np.float32), channel='train')
val_records = classifier_estimator.record_set(val_data.values[:, 1:].astype(np.float32), val_data.values[:, 0].astype(np.float32), channel='validation')
test_records = classifier_estimator.record_set(test_data.values[:, 1:].astype(np.float32), test_data.values[:, 0].astype(np.float32), channel='test')

# %%
# Fit the model
classifier_estimator.fit([train_records, val_records, test_records])
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: linear-learner-2024-11-01-07-52-25-935
# 2024-11-01 07:52:27 Starting - Starting the training job...
# 2024-11-01 07:52:41 Starting - Preparing the instances for training...
# 2024-11-01 07:53:09 Downloading - Downloading input data...
# 2024-11-01 07:53:59 Downloading - Downloading the training image......
# 2024-11-01 07:55:00 Training - Training image download completed. Training in progress.....Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [11/01/2024 07:55:23 INFO 139898924414784] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [11/01/2024 07:55:23 INFO 139898924414784] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'binary_classifier_model_selection_criteria': 'cross_entropy_loss', 'feature_dim': '93', 'mini_batch_size': '1000', 'predictor_type': 'binary_classifier'}
# [11/01/2024 07:55:23 INFO 139898924414784] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '93', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'cross_entropy_loss', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [11/01/2024 07:55:26 WARNING 139898924414784] Loggers have already been setup.
# [11/01/2024 07:55:26 INFO 139898924414784] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '93', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'cross_entropy_loss', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [11/01/2024 07:55:26 WARNING 139898924414784] Loggers have already been setup.
# Process 7 is a worker.
# [11/01/2024 07:55:26 INFO 139898924414784] Using default worker.
# [11/01/2024 07:55:26 INFO 139898924414784] Checkpoint loading and saving are disabled.
# [2024-11-01 07:55:26.911] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2024-11-01 07:55:26.914] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2024-11-01 07:55:26.954] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 47, "num_examples": 1, "num_bytes": 420000}
# [11/01/2024 07:55:26 INFO 139898924414784] Create Store: local
# [2024-11-01 07:55:27.073] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 117, "num_examples": 11, "num_bytes": 4620000}
# [11/01/2024 07:55:27 INFO 139898924414784] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f3c30df0a00>
# [11/01/2024 07:55:27 INFO 139898924414784] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [5.3811853e+02 4.3410933e-01 4.3667558e-01 4.3982100e-01 2.5065067e-01
#  2.7656806e-01 2.7697837e-01 2.7996090e-01 2.7505597e-01 2.8605148e-01
#  2.7833983e-01 2.7422616e-01 2.8644213e-01 2.8090027e-01 2.7982637e-01
#  1.8029132e-01 1.7648274e-01 1.7503001e-01 1.7744365e-01 1.7183441e-01
#  1.7934786e-01 1.7405383e-01 1.8076092e-01 1.8169598e-01 1.7863651e-01
#  1.8308818e-01 1.7934786e-01 1.7982031e-01 1.8052630e-01 1.8354957e-01
#  1.7672348e-01 1.7356342e-01 1.7478654e-01 1.7503004e-01 1.8853863e-01
#  1.7887397e-01 1.8052632e-01 1.7208262e-01 1.7158581e-01 1.8029130e-01
#  1.8400961e-01 1.7429848e-01 1.7058724e-01 1.7058724e-01 1.4062189e-01
#  3.5392460e-01 3.5025817e-01 3.6337170e-01 3.5769406e-01 3.2442924e-01
#  3.4307793e-01 3.7068751e-01 2.4426647e-01 4.5932102e-01 3.1254947e-01
#  2.4312642e-01 3.1836256e-01 3.2633841e-01 2.7087051e-01 3.5671464e-01
#  3.3570236e-01 3.0024230e-01 3.3337989e-01 2.4065953e-01 3.1858256e-01
#  3.2895830e-01 2.7615681e-01 3.5319734e-01 3.3888572e-01 3.0336428e-01
#  3.2591581e-01 5.9438076e-02 9.5341932e-03 9.5341932e-03 1.5612496e-01
#  2.3511353e-01 2.5002196e-01 2.5484034e-01 2.4279939e-01 2.4065956e-01
#  2.3782341e-01 2.4065955e-01 2.4049391e-01 2.4032813e-01 2.3339930e-01
#  2.4132058e-01 2.4361588e-01 2.2202703e-01 2.2744712e-01 1.9207254e-01
#  1.6021422e-01 1.6703898e-01 1.1090280e-01]
# <NDArray 93 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [1
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5195044568468641, "count": 1, "min": 0.5195044568468641, "max": 0.5195044568468641}}}
# #metrics {"StartTime": 1730447753.0441065, "EndTime": 1730447753.044116, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.509957796003435, "count": 1, "min": 0.509957796003435, "max": 0.509957796003435}}}
# #metrics {"StartTime": 1730447753.0441573, "EndTime": 1730447753.0441675, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.519648534734766, "count": 1, "min": 0.519648534734766, "max": 0.519648534734766}}}
# #metrics {"StartTime": 1730447753.0442083, "EndTime": 1730447753.044217, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4952347629787205, "count": 1, "min": 0.4952347629787205, "max": 0.4952347629787205}}}
# #metrics {"StartTime": 1730447753.0442553, "EndTime": 1730447753.0442648, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4956877179979444, "count": 1, "min": 0.4956877179979444, "max": 0.4956877179979444}}}
# #metrics {"StartTime": 1730447753.0442996, "EndTime": 1730447753.0443082, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4952741521555227, "count": 1, "min": 0.4952741521555227, "max": 0.4952741521555227}}}
# #metrics {"StartTime": 1730447753.044343, "EndTime": 1730447753.0443497, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.49566730760694383, "count": 1, "min": 0.49566730760694383, "max": 0.49566730760694383}}}
# #metrics {"StartTime": 1730447753.0443804, "EndTime": 1730447753.0443883, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5089178731158063, "count": 1, "min": 0.5089178731158063, "max": 0.5089178731158063}}}
# #metrics {"StartTime": 1730447753.0444214, "EndTime": 1730447753.0444303, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5176777389099548, "count": 1, "min": 0.5176777389099548, "max": 0.5176777389099548}}}
# #metrics {"StartTime": 1730447753.0444639, "EndTime": 1730447753.0444734, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5089178826658876, "count": 1, "min": 0.5089178826658876, "max": 0.5089178826658876}}}
# #metrics {"StartTime": 1730447753.0445077, "EndTime": 1730447753.0445151, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.517632282497166, "count": 1, "min": 0.517632282497166, "max": 0.517632282497166}}}
# #metrics {"StartTime": 1730447753.0445395, "EndTime": 1730447753.0445466, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5096579450860724, "count": 1, "min": 0.5096579450860724, "max": 0.5096579450860724}}}
# #metrics {"StartTime": 1730447753.04458, "EndTime": 1730447753.0445893, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5097295335622934, "count": 1, "min": 0.5097295335622934, "max": 0.5097295335622934}}}
# #metrics {"StartTime": 1730447753.04461, "EndTime": 1730447753.0446167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5096545402420151, "count": 1, "min": 0.5096545402420151, "max": 0.5096545402420151}}}
# #metrics {"StartTime": 1730447753.0446484, "EndTime": 1730447753.0446575, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5097456018674623, "count": 1, "min": 0.5097456018674623, "max": 0.5097456018674623}}}
# #metrics {"StartTime": 1730447753.0446863, "EndTime": 1730447753.0446951, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5109222535086678, "count": 1, "min": 0.5109222535086678, "max": 0.5109222535086678}}}
# #metrics {"StartTime": 1730447753.0447173, "EndTime": 1730447753.0447228, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5125415819074725, "count": 1, "min": 0.5125415819074725, "max": 0.5125415819074725}}}
# #metrics {"StartTime": 1730447753.0447402, "EndTime": 1730447753.0447452, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5109662471584506, "count": 1, "min": 0.5109662471584506, "max": 0.5109662471584506}}}
# #metrics {"StartTime": 1730447753.0447652, "EndTime": 1730447753.0447729, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5125703620110358, "count": 1, "min": 0.5125703620110358, "max": 0.5125703620110358}}}
# #metrics {"StartTime": 1730447753.0448086, "EndTime": 1730447753.0448182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5154400744671588, "count": 1, "min": 0.5154400744671588, "max": 0.5154400744671588}}}
# #metrics {"StartTime": 1730447753.0448482, "EndTime": 1730447753.0448563, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5
#quality_metric: host=algo-1, epoch=0, validation binary_classification_cross_entropy_objective <loss>=0.4920821119949904
# [11/01/2024 07:55:57 INFO 139898924414784] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.4920821119949904
# [11/01/2024 07:55:57 INFO 139898924414784] Epoch 0: Loss improved. Updating best model
# [11/01/2024 07:55:57 INFO 139898924414784] Saving model for epoch: 0
# [11/01/2024 07:55:57 INFO 139898924414784] Saved checkpoint to "/tmp/tmpe0whi0p9/mx-mod-0000.params"
# [11/01/2024 07:55:57 INFO 139898924414784] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1730447727.1923554, "EndTime": 1730447757.4858215, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1156913.0, "count": 1, "min": 1156913, "max": 1156913}, "Total Batches Seen": {"sum": 1157.0, "count": 1, "min": 1157, "max": 1157}, "Max Records Seen Between Resets": {"sum": 1144913.0, "count": 1, "min": 1144913, "max": 1144913}, "Max Batches Seen Between Resets": {"sum": 1145.0, "count": 1, "min": 1145, "max": 1145}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 1144913.0, "count": 1, "min": 1144913, "max": 1144913}, "Number of Batches Since Last Reset": {"sum": 1145.0, "count": 1, "min": 1145, "max": 1145}}}
# [11/01/2024 07:55:57 INFO 139898924414784] #throughput_metric: host=algo-1, train throughput=37793.92872672193 records/second
# [2024-11-01 07:56:24.042] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 26553, "num_examples": 1145, "num_bytes": 480863460}
# #metrics {"StartTime": 1730447784.0425138, "EndTime": 1730447784.0425768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.49248933477335044, "count": 1, "min": 0.49248933477335044, "max": 0.49248933477335044}}}
# #metrics {"StartTime": 1730447784.0426478, "EndTime": 1730447784.042663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4935006722937097, "count": 1, "min": 0.4935006722937097, "max": 0.4935006722937097}}}
# #metrics {"StartTime": 1730447784.0427034, "EndTime": 1730447784.0427146, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.49249342500913396, "count": 1, "min": 0.49249342500913396, "max": 0.49249342500913396}}}
# #metrics {"StartTime": 1730447784.04275, "EndTime": 1730447784.0427585, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4934971331616382, "count": 1, "min": 0.4934971331616382, "max": 0.4934971331616382}}}
# #metrics {"StartTime": 1730447784.0427866, "EndTime": 1730447784.0427954, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4977801322403488, "count": 1, "min": 0.4977801322403488, "max": 0.4977801322403488}}}
# #metrics {"StartTime": 1730447784.0428255, "EndTime": 1730447784.0428343, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5157718416227327, "count": 1, "min": 0.5157718416227327, "max": 0.5157718416227327}}}
# #metrics {"StartTime": 1730447784.0428646, "EndTime": 1730447784.0428746, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.49777765799569085, "count": 1, "min": 0.49777765799569085, "max": 0.49777765799569085}}}
# #metrics {"StartTime": 1730447784.042903, "EndTime": 1730447784.0429122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5158152195323598, "count": 1, "min": 0.5158152195323598, "max": 0.5158152195323598}}}
# #metrics {"StartTime": 1730447784.0429456, "EndTime": 1730447784.0429611, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.49265941267747143, "count": 1, "min": 0.49265941267747143, "max": 0.49265941267747143}}}
# #metrics {"StartTime": 1730447784.0429952, "EndTime": 1730447784.0430052, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4936309094729123, "count": 1, "min": 0.4936309094729123, "max": 0.4936309094729123}}}
# #metrics {"StartTime": 1730447784.0430307, "EndTime": 1730447784.043039, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.49265856386731555, "count": 1, "min": 0.49265856386731555, "max": 0.49265856386731555}}}
# #metrics {"StartTime": 1730447784.043075, "EndTime": 1730447784.0430837, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4936309118737708, "count": 1, "min": 0.4936309118737708, "max": 0.4936309118737708}}}
# #metrics {"StartTime": 1730447784.043112, "EndTime": 1730447784.0431201, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4976600380477372, "count": 1, "min": 0.4976600380477372, "max": 0.4976600380477372}}}
# #metrics {"StartTime": 1730447784.0431507, "EndTime": 1730447784.043159, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5142647351618413, "count": 1, "min": 0.5142647351618413, "max": 0.5142647351618413}}}
# #metrics {"StartTime": 1730447784.0431886, "EndTime": 1730447784.043198, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 12}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.491897208718495, "count": 1, "min": 0.491897208718495, "max": 0.491897208718495}}}
# #metrics {"StartTime": 1730447879.0200908, "EndTime": 1730447879.0201006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 13}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5093249311102661, "count": 1, "min": 0.5093249311102661, "max": 0.5093249311102661}}}
# #metrics {"StartTime": 1730447879.0201344, "EndTime": 1730447879.020144, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 14}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.4918972059197214, "count": 1, "min": 0.4918972059197214, "max": 0.4918972059197214}}}
# #metrics {"StartTime": 1730447879.020178, "EndTime": 1730447879.0201879, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 15}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5093249743979639, "count": 1, "min": 0.5093249743979639, "max": 0.5093249743979639}}}
# #metrics {"StartTime": 1730447879.020222, "EndTime": 1730447879.0202322, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 16}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.507752194141945, "count": 1, "min": 0.507752194141945, "max": 0.507752194141945}}}
# #metrics {"StartTime": 1730447879.0202622, "EndTime": 1730447879.0202715, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 17}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5079368582165933, "count": 1, "min": 0.5079368582165933, "max": 0.5079368582165933}}}
# #metrics {"StartTime": 1730447879.020302, "EndTime": 1730447879.0203118, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 18}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5078388922480916, "count": 1, "min": 0.5078388922480916, "max": 0.5078388922480916}}}
# #metrics {"StartTime": 1730447879.0203514, "EndTime": 1730447879.020362, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 19}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5079368977103981, "count": 1, "min": 0.5079368977103981, "max": 0.5079368977103981}}}
# #metrics {"StartTime": 1730447879.020398, "EndTime": 1730447879.0204084, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 20}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5078564766313981, "count": 1, "min": 0.5078564766313981, "max": 0.5078564766313981}}}
# #metrics {"StartTime": 1730447879.020451, "EndTime": 1730447879.0204613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 21}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5133758013279288, "count": 1, "min": 0.5133758013279288, "max": 0.5133758013279288}}}
# #metrics {"StartTime": 1730447879.020493, "EndTime": 1730447879.0205028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 22}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5078564794923667, "count": 1, "min": 0.5078564794923667, "max": 0.5078564794923667}}}
# #metrics {"StartTime": 1730447879.0205338, "EndTime": 1730447879.0205424, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 23}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.51337576003047, "count": 1, "min": 0.51337576003047, "max": 0.51337576003047}}}
# #metrics {"StartTime": 1730447879.0205793, "EndTime": 1730447879.0205884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 24}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5137617089764339, "count": 1, "min": 0.5137617089764339, "max": 0.5137617089764339}}}
# #metrics {"StartTime": 1730447879.0206203, "EndTime": 1730447879.0206296, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 25}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5137946382266386, "count": 1, "min": 0.5137946382266386, "max": 0.5137946382266386}}}
# #metrics {"StartTime": 1730447879.0206609, "EndTime": 1730447879.0206707, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 26}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.513761772975056, "count": 1, "min": 0.513761772975056, "max": 0.513761772975056}}}
# #metrics {"StartTime": 1730447879.0207007, "EndTime": 1730447879.0207102, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 27}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5137953308919974, "count": 1, "min": 0.5137953308919974, "max": 0.5137953308919974}}}
# #metrics {"StartTime": 1730447879.0207505, "EndTime": 1730447879.020761, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 28}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.513763795182246, "count": 1, "min": 0.513763795182246, "max": 0.513763795182246}}}
# #metrics {"StartTime": 1730447879.0207949, "EndTime": 1730447879.0208051, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 29}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.516282822369396, "count": 1, "min": 0.516282822369396, "max": 0.516282822369396}}}
# #metrics {"StartTime": 1730447879.0208359, "EndTime": 1730447879.0208437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 30}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5137696647701573, "count": 1, "min": 0.5137696647701573, "max": 0.5137696647701573}}}
# #metrics {"StartTime": 1730447879.0208726, "EndTime": 1730447879.0208814, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 31}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5162827748524405, "count": 1, "min": 0.5162827748524405, "max": 0.5162827748524405}}}
# [11/01/2024 07:57:59 INFO 139898924414784] #quality_metric: host=algo-1, epoch=4, validation binary_classification_cross_entropy_objective <loss>=0.49152397870568487
# [11/01/2024 07:57:59 INFO 139898924414784] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=binary_classification_cross_entropy_objective, value=0.49152397870568487
# [11/01/2024 07:57:59 INFO 139898924414784] Saving model for epoch: 4
# [11/01/2024 07:57:59 INFO 139898924414784] Saved checkpoint to "/tmp/tmpbyn_zmn5/mx-mod-0000.params"
# [11/01/2024 07:57:59 INFO 139898924414784] Early stop condition met. Stopping training.
# [11/01/2024 07:57:59 INFO 139898924414784] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1730447848.8731036, "EndTime": 1730447879.0274994, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 5736565.0, "count": 1, "min": 5736565, "max": 5736565}, "Total Batches Seen": {"sum": 5737.0, "count": 1, "min": 5737, "max": 5737}, "Max Records Seen Between Resets": {"sum": 1144913.0, "count": 1, "min": 1144913, "max": 1144913}, "Max Batches Seen Between Resets": {"sum": 1145.0, "count": 1, "min": 1145, "max": 1145}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 1144913.0, "count": 1, "min": 1144913, "max": 1144913}, "Number of Batches Since Last Reset": {"sum": 1145.0, "count": 1, "min": 1145, "max": 1145}}}
# [11/01/2024 07:57:59 INFO 139898924414784] #throughput_metric: host=algo-1, train throughput=37968.2074560528 records/second
# [11/01/2024 07:57:59 WARNING 139898924414784] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/01/2024 07:57:59 WARNING 139898924414784] wait_for_all_workers will not sync workers since the kv store is not running distributed
#
# 2024-11-01 07:58:13 Uploading - Uploading generated training model[2024-11-01 07:58:03.362] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 17, "duration": 4319, "num_examples": 246, "num_bytes": 103041960}
# [11/01/2024 07:58:03 INFO 139898924414784] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=binary_classification_cross_entropy_objective, value=0.49152397870568487
# [2024-11-01 07:58:04.738] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 19, "duration": 1366, "num_examples": 246, "num_bytes": 103041960}
# [11/01/2024 07:58:05 INFO 139898924414784] #validation_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.4920821119949904)
# [11/01/2024 07:58:05 INFO 139898924414784] #validation_score (algo-1) : ('binary_classification_accuracy', 0.7902281750075406)
# [11/01/2024 07:58:05 INFO 139898924414784] #validation_score (algo-1) : ('binary_f_1.000', 0.004834187373102581)
# [11/01/2024 07:58:05 INFO 139898924414784] #validation_score (algo-1) : ('precision', 0.5813953488372093)
# [11/01/2024 07:58:05 INFO 139898924414784] #validation_score (algo-1) : ('recall', 0.0024271844660194173)
# [11/01/2024 07:58:05 INFO 139898924414784] #validation_score (algo-1) : ('roc_auc_score', 0.6443758385167396)
# [11/01/2024 07:58:05 INFO 139898924414784] #validation_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [11/01/2024 07:58:05 INFO 139898924414784] #validation_score (algo-1) : ('binary_log_loss', 0.7521984959414452)
# [11/01/2024 07:58:05 INFO 139898924414784] #quality_metric: host=algo-1, validation binary_classification_cross_entropy_objective <loss>=0.4920821119949904
# [11/01/2024 07:58:05 INFO 139898924414784] #quality_metric: host=algo-1, validation binary_classification_accuracy <score>=0.7902281750075406
# [11/01/2024 07:58:05 INFO 139898924414784] #quality_metric: host=algo-1, validation binary_f_1.000 <score>=0.004834187373102581
# [11/01/2024 07:58:05 INFO 139898924414784] #quality_metric: host=algo-1, validation precision <score>=0.5813953488372093
# [11/01/2024 07:58:05 INFO 139898924414784] #quality_metric: host=algo-1, validation recall <score>=0.0024271844660194173
# [11/01/2024 07:58:05 INFO 139898924414784] #quality_metric: host=algo-1, validation roc_auc_score <score>=0.6443758385167396
# [11/01/2024 07:58:05 INFO 139898924414784] #quality_metric: host=algo-1, validation binary_balanced_accuracy <score>=0.5
# [11/01/2024 07:58:05 INFO 139898924414784] #quality_metric: host=algo-1, validation binary_log_loss <score>=0.7521984959414452
# [11/01/2024 07:58:05 INFO 139898924414784] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "l1": 0.0, "wd": 0.0001, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [11/01/2024 07:58:05 INFO 139898924414784] Saved checkpoint to "/tmp/tmpdw3i_z6e/mx-mod-0000.params"
# [2024-11-01 07:58:05.116] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 158201, "num_examples": 1, "num_bytes": 420000}
# [2024-11-01 07:58:05.976] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 860, "num_examples": 246, "num_bytes": 103042380}
# #metrics {"StartTime": 1730447885.116, "EndTime": 1730447886.3365178, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "test_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 245339.0, "count": 1, "min": 245339, "max": 245339}, "Total Batches Seen": {"sum": 246.0, "count": 1, "min": 246, "max": 246}, "Max Records Seen Between Resets": {"sum": 245339.0, "count": 1, "min": 245339, "max": 245339}, "Max Batches Seen Between Resets": {"sum": 246.0, "count": 1, "min": 246, "max": 246}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 245339.0, "count": 1, "min": 245339, "max": 245339}, "Number of Batches Since Last Reset": {"sum": 246.0, "count": 1, "min": 246, "max": 246}}}
# [11/01/2024 07:58:06 INFO 139898924414784] #test_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.4921127266532625)
# [11/01/2024 07:58:06 INFO 139898924414784] #test_score (algo-1) : ('binary_classification_accuracy', 0.7902004980863214)
# [11/01/2024 07:58:06 INFO 139898924414784] #test_score (algo-1) : ('binary_f_1.000', 0.004833533119368934)
# [11/01/2024 07:58:06 INFO 139898924414784] #test_score (algo-1) : ('precision', 0.5630630630630631)
# [11/01/2024 07:58:06 INFO 139898924414784] #test_score (algo-1) : ('recall', 0.0024271844660194173)
# [11/01/2024 07:58:06 INFO 139898924414784] #test_score (algo-1) : ('roc_auc_score', 0.6450338121162207)
# [11/01/2024 07:58:06 INFO 139898924414784] #test_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [11/01/2024 07:58:06 INFO 139898924414784] #test_score (algo-1) : ('binary_log_loss', 0.752375854369371)
# [11/01/2024 07:58:06 INFO 139898924414784] #quality_metric: host=algo-1, test binary_classification_cross_entropy_objective <loss>=0.4921127266532625
# [11/01/2024 07:58:06 INFO 139898924414784] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.7902004980863214
# [11/01/2024 07:58:06 INFO 139898924414784] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.004833533119368934
# [11/01/2024 07:58:06 INFO 139898924414784] #quality_metric: host=algo-1, test precision <score>=0.5630630630630631
# [11/01/2024 07:58:06 INFO 139898924414784] #quality_metric: host=algo-1, test recall <score>=0.0024271844660194173
# [11/01/2024 07:58:06 INFO 139898924414784] #quality_metric: host=algo-1, test roc_auc_score <score>=0.6450338121162207
# [11/01/2024 07:58:06 INFO 139898924414784] #quality_metric: host=algo-1, test binary_balanced_accuracy <score>=0.5
# [11/01/2024 07:58:06 INFO 139898924414784] #quality_metric: host=algo-1, test binary_log_loss <score>=0.752375854369371
# #metrics {"StartTime": 1730447726.9062705, "EndTime": 1730447886.3443906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 258.0087184906006, "count": 1, "min": 258.0087184906006, "max": 258.0087184906006}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 1.6541481018066406, "count": 6, "min": 0.1773834228515625, "max": 0.5810260772705078}, "update.time": {"sum": 151813.51852416992, "count": 5, "min": 30150.83622932434, "max": 30624.465227127075}, "finalize.time": {"sum": 6084.782123565674, "count": 1, "min": 6084.782123565674, "max": 6084.782123565674}, "setuptime": {"sum": 1.9490718841552734, "count": 1, "min": 1.9490718841552734, "max": 1.9490718841552734}, "totaltime": {"sum": 159552.4456501007, "count": 1, "min": 159552.4456501007, "max": 159552.4456501007}}}
#
# 2024-11-01 07:58:26 Completed - Training job completed
# Training seconds: 316
# Billable seconds: 316

# %%
# Model Evaluation

sagemaker.analytics.TrainingJobAnalytics(classifier_estimator._current_job_name, 
                                         metric_names = ['test:objective_loss', 
                                                         'test:binary_f_beta',
                                                         'test:precision',
                                                         'test:recall']
                                        ).dataframe()
# Out:
#    timestamp          metric_name     value
# 0        0.0  test:objective_loss  0.492113
# 1        0.0   test:binary_f_beta  0.004834
# 2        0.0       test:precision  0.563063
# 3        0.0          test:recall  0.002427

# %%
# Hosting the model

import sagemaker

# Assume linear_estimator has already been defined and trained
predictor = classifier_estimator.deploy(
    initial_instance_count=1,  # Number of instances
    instance_type='ml.m4.xlarge', 
    endpoint_name='flight-delay-endpoint'
)

print("Model deployed. Endpoint name:", predictor.endpoint_name)
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating model with name: linear-learner-2024-11-01-08-35-38-549
# INFO:sagemaker:Creating endpoint-config with name flight-delay-endpoint
# INFO:sagemaker:Creating endpoint with name flight-delay-endpoint
# ---------!Model deployed. Endpoint name: flight-delay-endpoint

# %%
# Batch Transformer

def batch_linear_predict(test_data, estimator):
    batch_X = test_data.iloc[:,1:];
    batch_X_file='batch-in.csv'
    upload_s3_csv(batch_X_file, 'batch-in', batch_X)

    batch_output = "s3://{}/{}/batch-out/".format(bucket,prefix)
    batch_input = "s3://{}/{}/batch-in/{}".format(bucket,prefix,batch_X_file)

    classifier_transformer = estimator.transformer(instance_count=1,
                                           instance_type='ml.m4.xlarge',
                                           strategy='MultiRecord',
                                           assemble_with='Line',
                                           output_path=batch_output)

    classifier_transformer.transform(data=batch_input,
                             data_type='S3Prefix',
                             content_type='text/csv',
                             split_type='Line')
    
    classifier_transformer.wait()

    s3 = boto3.client('s3')
    obj = s3.get_object(Bucket=bucket, Key="{}/batch-out/{}".format(prefix,'batch-in.csv.out'))
    target_predicted_df = pd.read_json(io.BytesIO(obj['Body'].read()),orient="records",lines=True)
    return test_data.iloc[:,0], target_predicted_df.iloc[:,0]

# %%
test_labels, target_predicted = batch_linear_predict(test_data, classifier_estimator)
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating model with name: linear-learner-2024-11-01-08-01-18-082
# INFO:sagemaker:Creating transform job with name: linear-learner-2024-11-01-08-01-18-757
# ...................................................
# Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# [11/01/2024 08:09:49 INFO 140006038705984] Memory profiler is not enabled by the environment variable ENABLE_PROFILER.
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [11/01/2024 08:09:52 WARNING 140006038705984] Loggers have already been setup.
# [11/01/2024 08:09:52 INFO 140006038705984] loaded entry point class algorithm.serve.server_config:config_api
# [11/01/2024 08:09:52 INFO 140006038705984] loading entry points
# [11/01/2024 08:09:52 INFO 140006038705984] loaded request iterator application/json
# [11/01/2024 08:09:52 INFO 140006038705984] loaded request iterator application/jsonlines
# [11/01/2024 08:09:52 INFO 140006038705984] loaded request iterator application/x-recordio-protobuf
# [11/01/2024 08:09:52 INFO 140006038705984] loaded request iterator text/csv
# [11/01/2024 08:09:52 INFO 140006038705984] loaded response encoder application/json
# [11/01/2024 08:09:52 INFO 140006038705984] loaded response encoder application/jsonlines
# [11/01/2024 08:09:52 INFO 140006038705984] loaded response encoder application/x-recordio-protobuf
# [11/01/2024 08:09:52 INFO 140006038705984] loaded response encoder text/csv
# [11/01/2024 08:09:53 INFO 140006038705984] loaded entry point class algorithm:model
# [11/01/2024 08:09:53 INFO 140006038705984] Number of server workers: 4
# [11/01/2024 08:09:53 INFO 140006038705984] loading model...
# [11/01/2024 08:09:53 INFO 140006038705984] ...model loaded.
# [2024-11-01 08:09:53 +0000] [1] [INFO] Starting gunicorn 20.1.0
# [2024-11-01 08:09:53 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2024-11-01 08:09:53 +0000] [1] [INFO] Using worker: sync
# [2024-11-01 08:09:53 +0000] [43] [INFO] Booting worker with pid: 43
# [2024-11-01 08:09:53 +0000] [52] [INFO] Booting worker with pid: 52
# [2024-11-01 08:09:53 +0000] [61] [INFO] Booting worker with pid: 61
# [2024-11-01 08:09:53 +0000] [70] [INFO] Booting worker with pid: 70
# #metrics {"StartTime": 1730448593.0242307, "EndTime": 1730448593.7247956, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"execution_parameters.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1730448593.0242307, "EndTime": 1730448596.2726653, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 104.38084602355957, "count": 1, "min": 104.38084602355957, "max": 104.38084602355957}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1730448593.725593, "EndTime": 1730448596.4599185, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 118.87502670288086, "count": 1, "min": 118.87502670288086, "max": 118.87502670288086}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1730448593.0242307, "EndTime": 1730448596.4679677, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 99.82514381408691, "count": 1, "min": 99.82514381408691, "max": 99.82514381408691}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1730448593.0242307, "EndTime": 1730448596.8039122, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 120.5739974975586, "count": 1, "min": 120.5739974975586, "max": 120.5739974975586}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1730448596.8040433, "EndTime": 1730448597.5957034, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 54.7487735748291, "count": 1, "min": 54.7487735748291, "max": 54.7487735748291}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1730448596.4680824, "EndTime": 1730448597.723798, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 105.93748092651367, "count": 1, "min": 105.93748092651367, "max": 105.93748092651367}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1730448596.4600172, "EndTime": 1730448597.8469026, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 115.5846118927002, "count": 1, "min": 115.5846118927002, "max": 115.5846118927002}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1730448596.273174, "EndTime": 1730448597.9113994, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 89.35546875, "count": 1, "min": 89.35546875, "max": 89.35546875}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1730448596.8040433, "EndTime": 1730448597.5957034, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 54.7487735748291, "count": 1, "min": 54.7487735748291, "max": 54.7487735748291}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1730448596.4680824, "EndTime": 1730448597.723798, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 105.93748092651367, "count": 1, "min": 105.93748092651367, "max": 105.93748092651367}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1730448596.4600172, "EndTime": 1730448597.8469026, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 115.5846118927002, "count": 1, "min": 115.5846118927002, "max": 115.5846118927002}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1730448596.273174, "EndTime": 1730448597.9113994, "Dimensions": {"Algorithm": "LinearLearnerModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"json.encoder.time": {"sum": 89.35546875, "count": 1, "min": 89.35546875, "max": 89.35546875}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# 2024-11-01T08:09:53.732:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# [11/01/2024 08:09:49 INFO 140006038705984] Memory profiler is not enabled by the environment variable ENABLE_PROFILER.
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [11/01/2024 08:09:52 WARNING 140006038705984] Loggers have already been setup.
# [11/01/2024 08:09:52 INFO 140006038705984] loaded entry point class algorithm.serve.server_config:config_api
# [11/01/2024 08:09:52 INFO 140006038705984] loading entry points
# [11/01/2024 08:09:52 INFO 140006038705984] loaded request iterator application/json
# [11/01/2024 08:09:52 INFO 140006038705984] loaded request iterator application/jsonlines
# [11/01/2024 08:09:52 INFO 140006038705984] loaded request iterator application/x-recordio-protobuf
# [11/01/2024 08:09:52 INFO 140006038705984] loaded request iterator text/csv
# [11/01/2024 08:09:52 INFO 140006038705984] loaded response encoder application/json
# Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# [11/01/2024 08:09:49 INFO 140006038705984] Memory profiler is not enabled by the environment variable ENABLE_PROFILER.
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [11/01/2024 08:09:52 WARNING 140006038705984] Loggers have already been setup.
# [11/01/2024 08:09:52 INFO 140006038705984] loaded entry point class algorithm.serve.server_config:config_api
# [11/01/2024 08:09:52 INFO 140006038705984] loading entry points
# [11/01/2024 08:09:52 INFO 140006038705984] loaded request iterator application/json
# [11/01/2024 08:09:52 INFO 140006038705984] loaded request iterator application/jsonlines
# [11/01/2024 08:09:52 INFO 140006038705984] loaded request iterator application/x-recordio-protobuf
# [11/01/2024 08:09:52 INFO 140006038705984] loaded request iterator text/csv
# [11/01/2024 08:09:52 INFO 140006038705984] loaded response encoder application/json
# [11/01/2024 08:09:52 INFO 140006038705984] loaded response encoder application/jsonlines
# [11/01/2024 08:09:52 INFO 140006038705984] loaded response encoder application/x-recordio-protobuf
# [11/01/2024 08:09:52 INFO 140006038705984] loaded response encoder text/csv
# [11/01/2024 08:09:53 INFO 140006038705984] loaded entry point class algorithm:model
# [11/01/2024 08:09:53 INFO 140006038705984] Number of server workers: 4
# [11/01/2024 08:09:53 INFO 140006038705984] loading model...
# [11/01/2024 08:09:53 INFO 140006038705984] ...model loaded.
# [2024-11-01 08:09:53 +0000] [1] [INFO] Starting gunicorn 20.1.0
# [
sklearn.metrics import confusion_matrix

def plot_confusion_matrix(test_labels, target_predicted):
    matrix = confusion_matrix(test_labels, target_predicted)
    df_confusion = pd.DataFrame(matrix)
    colormap = sns.color_palette("BrBG", 10)
    sns.heatmap(df_confusion, annot=True, fmt='.2f', cbar=None, cmap=colormap)
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.ylabel("True Class")
    plt.xlabel("Predicted Class")
    plt.show()

# %%
matrix = confusion_matrix(test_labels, target_predicted)
matrix
# Out:
# array([[193742,     97],
#        [ 51375,    125]])

# %%
plot_confusion_matrix(test_labels, target_predicted)

# %% [markdown]
# The linear estimator model 1 struggles to accurately predict delays. While it correctly identifies 193,742 instances as "No Delay" (true negatives), it misclassifies a significant number of actual delays as "No Delay." Specifically, 51,375 instances of "Delay" were incorrectly labeled as "No Delay" (false negatives). This high false negative rate undermines the model's reliability for predicting delays, despite its strong performance in identifying "No Delay" cases.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_curve, auc, roc_auc_score

def plot_roc(test_labels, target_predicted):
    # Calculate confusion matrix components
    TN, FP, FN, TP = confusion_matrix(test_labels, target_predicted).ravel()
    
    # Calculate various metrics
    Sensitivity = float(TP) / (TP + FN) * 100 if (TP + FN) > 0 else 0
    Specificity = float(TN) / (TN + FP) * 100 if (TN + FP) > 0 else 0
    Precision = float(TP) / (TP + FP) * 100 if (TP + FP) > 0 else 0
    NPV = float(TN) / (TN + FN) * 100 if (TN + FN) > 0 else 0
    FPR = float(FP) / (FP + TN) * 100 if (FP + TN) > 0 else 0
    FNR = float(FN) / (TP + FN) * 100 if (TP + FN) > 0 else 0
    FDR = float(FP) / (TP + FP) * 100 if (TP + FP) > 0 else 0
    ACC = float(TP + TN) / (TP + FP + FN + TN) * 100 if (TP + FP + FN + TN) > 0 else 0

    # Print metrics
    print("Sensitivity or TPR: ", Sensitivity, "%") 
    print("Specificity or TNR: ", Specificity, "%") 
    print("Precision: ", Precision, "%") 
    print("Negative Predictive Value: ", NPV, "%") 
    print("False Positive Rate: ", FPR, "%")
    print("False Negative Rate: ", FNR, "%") 
    print("False Discovery Rate: ", FDR, "%")
    print("Accuracy: ", ACC, "%") 

    # Calculate AUC
    auc_value = roc_auc_score(test_labels, target_predicted)
    print("Validation AUC:", auc_value)

    # Calculate ROC curve
    fpr, tpr, thresholds = roc_curve(test_labels, target_predicted)
    roc_auc = auc(fpr, tpr)

    # Plot ROC curve
    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")

    # Create the axis for thresholds
    ax2 = plt.gca().twinx()
    ax2.plot(fpr, thresholds, markeredgecolor='r', linestyle='dashed', color='r')
    ax2.set_ylabel('Threshold', color='r')

# %%
plot_roc(test_labels, target_predicted)
# Out:
# Sensitivity or TPR:  0.24271844660194172 %
# Specificity or TNR:  99.9499584706896 %
# Precision:  56.30630630630631 %
# Negative Predictive Value:  79.04062141752713 %
# False Positive Rate:  0.05004152931040709 %
# False Negative Rate:  99.75728155339806 %
# False Discovery Rate:  43.69369369369369 %
# Accuracy:  79.02004980863214 %
# Validation AUC: 0.5009633845864577

# %% [markdown]
# The linear estimator model 1, while demonstrating strong performance in identifying "No Delay" cases with a high specificity of 99.95%, struggles to accurately predict "Delay" instances. The model's sensitivity of 0.24% indicates a high false negative rate, meaning it fails to correctly identify a significant portion of actual delays. Additionally, its precision of 56.31% and negative predictive value of 79.04% suggest that while it can correctly identify some delays, it also makes a substantial number of incorrect positive predictions. Overall, the model's performance, as measured by an accuracy of 79.02% and a validation AUC of 0.5009, is limited in its ability to reliably predict delays.
